# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from ttc_core.file_helper import PROJECT_ROOT
from ttc_server.services.llm_service import LLMService
from ttc_server.mocks.mock_llm_client import MockLLMClient

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

service = LLMService(
    MockLLMClient("""{
  "start": "20260330T140000Z",
  "end": "20260330T160000Z",
  "summary": "Birthday Party",
  "description": "Come celebrate my birthday!",
  "location": "London Eye"
}""")
)

prompt = """
Hey are you able to make it to my birthday? Its at 3pm on Sunday 30th March 2026,
at the London Eye.
"""

service.calendar_event_from_prompt(prompt).model_dump()
# Out:
# {'uid': 'a7071c95-878d-4f99-82d3-aec270163f22@prompt-to-calendar.taurho.co.uk',
#  'dtstamp': datetime.datetime(2026, 3, 16, 22, 9, 12, 242449),
#  'dtstart': datetime.datetime(2026, 3, 30, 14, 0),
#  'dtend': datetime.datetime(2026, 3, 30, 16, 0),
#  'summary': 'Birthday Party',
#  'description': 'Come celebrate my birthday!',
#  'location': 'London Eye',
#  'status': 'CONFIRMED'}
