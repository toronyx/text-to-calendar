# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ptc_server.clients.llm.gemini_client import GeminiClient
from ptc_server.logger_config import setup_logging
from ptc_server.services.llm_service import LLMService

# setup_logging()

service = LLMService(GeminiClient())

prompt = """
Hey are you able to make it to my birthday? Its at 3pm on Sunday 30th March 2026,
at the London Eye.
"""

service.calendar_event_from_prompt(prompt).model_dump()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 15
#       8 service = MockLLMService(GeminiClient())
#      10 prompt = """
#      11 Hey are you able to make it to my birthday? Its at 3pm on Sunday 30th March 2026,
#      12 at the London Eye.
#      13 """
# ---> 15 service.calendar_event_from_prompt(prompt).model_dump()
#
# AttributeError: 'MockLLMService' object has no attribute 'calendar_event_from_prompt'
